# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Integer**

# %%
8
# Out:
# 8

# %%
type(8)
# Out:
# int

# %%
type(6.4)
# Out:
# float

# %%
a=6

# %%
type(a)
# Out:
# int

# %%
name="my name is srija"

# %%
print(name)
# Out:
# my name is srija

# %%
a
# Out:
# 6

# %% [markdown]
# **Working With Integers**

# %%
4+8 #addition
# Out:
# 12

# %%
-9-8 #substraction
# Out:
# -17

# %%
17*12 #multiplication
# Out:
# 204

# %%
121/10 #divide
# Out:
# 12.1

# %%
17%7 #reminder
# Out:
# 3

# %% [markdown]
# **presidence/priority of operators**

# %%
8*6/8
# Out:
# 6.0

# %%
4*5*8
# Out:
# 160

# %%
2+7*9
# Out:
# 65

# %%
5*(2+8)
# Out:
# 50

# %%
7/4
# Out:
# 1.75

# %%
7//4
# Out:
# 1

# %% [markdown]
# **Thank You**

# %% [markdown]
# **Float**

# %%
4.5
# Out:
# 4.5

# %%
type(4.5)
# Out:
# float

# %%
x=8.7

# %%
x
# Out:
# 8.7

# %%
type(x)
# Out:
# float

# %% [markdown]
# **Working With Float**

# %%
5.7+8.9
# Out:
# 14.600000000000001

# %%
5.6*2.4
# Out:
# 13.44

# %%
y=input()
# Out:
# 5.4

# %%
type(y)
# Out:
# str

# %%
y=float(input())
# Out:
# 5.4

# %%
type(y)
# Out:
# float

# %% [markdown]
# **Complex Number**

# %%
5+6j
# Out:
# (5+6j)

# %%
6j+5
# Out:
# (5+6j)

# %%
a=3+6j

# %%
type(a)
# Out:
# complex

# %%
d=input()
# Out:
# 8+9j

# %%
type(d)
# Out:
# str

# %%
d=complex(input())
# Out:
# 9+7j

# %%
type(d)
# Out:
# complex

# %% [markdown]
# **Working With Complex Data Types**

# %%
9+6j + 7+6j
# Out:
# (16+12j)

# %%
a=8+3j
b=9+4j
c=7+5j

# %%
a+b+c
# Out:
# (24+12j)

# %%
a*3
# Out:
# (24+9j)

# %%
a*c #doubt on calculation
# Out:
# (41+61j)

# %% [markdown]
# **Boolean**

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
a=True

# %%
type(a)
# Out:
# bool

# %% [markdown]
# **Working With Boolean**

# %%
a=True
b=False

# %%
a+b
# Out:
# 1

# %%
a-b
# Out:
# 1

# %%
a*b
# Out:
# 0

# %%
b/a
# Out:
# 0.0

# %%
a=input()
# Out:
# True

# %%
type(a)
# Out:
# str

# %%
a=bool(input())
# Out:
# True

# %%
type(a)
# Out:
# bool

# %%
type(a+b)
# Out:
# int

# %% [markdown]
# **String**

# %%
z='Pooh'

# %%
type(z)
# Out:
# str

# %%
y=4

# %%
type(y)
# Out:
# int

# %% [markdown]
# **Working With String**

# %%
b='My Name is Jovi'

# %%
b[4]
# Out:
# 'a'

# %%
b[9]
# Out:
# 's'

# %%
b[-4]
# Out:
# 'J'

# %%
b[-7]
# Out:
# 'i'

# %%
b[2+3]
# Out:
# 'm'

# %%
b[2:10]
# Out:
# ' Name is'

# %%
b.upper()
# Out:
# 'MY NAME IS JOVI'

# %%
b.lower()
# Out:
# 'my name is jovi'

# %%
b.replace('jovi','Jovi')
# Out:
# 'My Name is Jovi'

# %%
b.replace('Jovi','joyi')
# Out:
# 'My Name is joyi'

# %% [markdown]
# **Thank You**
